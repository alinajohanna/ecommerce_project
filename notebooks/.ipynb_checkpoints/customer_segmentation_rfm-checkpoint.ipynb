# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timezone



from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('../data/cleaned/customer_information.csv')

# %%
df.head()
# Out:
#    user_id          registration_date  age gender          city  \
# 0       18  2020-06-18 10:15:00+00:00   31      M  Schwedt/Oder
# 1       29  2023-09-22 07:18:00+00:00   23      M        Pudsey
# 2       49  2023-04-11 02:46:00+00:00   62      M      Bailleul
# 3       50  2023-05-01 13:46:00+00:00   15      F       Linares
# 4       51  2019-07-11 00:19:00+00:00   66      M        Siegen
#
#           country           first_order_date            last_order_date  \
# 0          Poland  2021-05-26 10:15:00+00:00  2021-05-26 10:15:00+00:00
# 1  United Kingdom  2023-11-29 07:18:00+00:00  2023-11-29 07:18:00+00:00
# 2          France  2023-08-20 02:46:00+00:00  2023-08-20 02:46:00+00:00
# 3           Spain  2023-07-10 13:46:00+00:00  2023-09-27 13:46:00+00:00
# 4         Germany  2021-08-15 00:19:00+00:00  2021-08-15 00:19:00+00:00
#
#    total_orders  avg_order_items  total_revenue  avg_order_value  \
# 0             1              1.0      46.990002        46.990002
# ...

# %%
df.shape
# Out:
# (14183, 17)

# %% [markdown]
# The dataframe already contains all columns needed to create the RFM model.
# Let's select them:

# %%
rfm_df = df[['user_id', 'days_since_last_order', 'total_orders', 'total_revenue']]
rfm_df.columns = ['user_id', 'recency', 'frequency', 'monetary']

# %%
rfm_df
# Out:
#        user_id     recency  frequency    monetary
# 0           18  974.505316          1   46.990002
# 1           29   57.628233          1   65.680000
# 2           49  158.817122          1   65.000000
# 3           50  120.358788          2  512.740005
# 4           51  893.919205          1  120.000000
# ...        ...         ...        ...         ...
# 14178    99951  711.496288          1   46.000000
# 14179    99962  369.285177          3  347.940004
# 14180    99982  752.416427          2  383.900002
# 14181    99997   88.411566          1   12.950000
# 14182    99999   30.229622          2   96.000000
#
# [14183 rows x 4 columns]

# %% [markdown]
# In the next step, Kmeans clustering will be performed in order to decide how to cluster the customers

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler

#transformed_df = rfm_df[['recency', 'frequency', 'monetary']]
scaled_df = rfm_df[['recency', 'frequency', 'monetary']]
scaler = StandardScaler()
#transformer = PowerTransformer(method='yeo-johnson')

#transformed = transformer.fit_transform(transformed_df)
scaled = scaler.fit_transform(scaled_df)
rfm_df = pd.DataFrame(scaled, columns=scaled_df.columns)
rfm_df
# Out:
#         recency  frequency  monetary
# 0      1.643380  -0.793872 -0.708619
# 1     -0.910479  -0.793872 -0.447802
# 2     -0.244057  -0.793872 -0.455861
# 3     -0.448368   1.038056  1.072110
# 4      1.527016  -0.793872  0.013133
# ...         ...        ...       ...
# 14178  1.234135  -0.793872 -0.725304
# 14179  0.500980   1.505890  0.796823
# 14180  1.303954   1.038056  0.867169
# 14181 -0.655348  -0.793872 -1.730578
# 14182 -1.233521   1.038056 -0.156159
#
# [14183 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

sse={}
recency = rfm_df[['recency']]

for k in range(1,10):
    kmeans = KMeans(n_clusters=k, max_iter=1000, random_state=42, n_init='auto').fit(recency)
    recency['clusters'] = kmeans.labels_
    sse[k] = kmeans.inertia_
    
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of clusters")
plt.show()
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1241748581.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1241748581.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1241748581.py:8: SettingWithCopyWarning:
# ...

# %% [markdown]
# Elbow somewhere at k=3 or k=4

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(rfm_df[['recency']])
rfm_df['recency_cluster'] = kmeans.predict(rfm_df[['recency']])
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Evaluate the clustering using silhouette score
silhouette_avg = silhouette_score(rfm_df[['recency']], rfm_df['recency_cluster'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.5582565452644228

# %%
def order_cluster(clusters: str, score: str, df: pd.DataFrame, ascending):
    """
    Takes the generated clusters, orders them and assigns them to the final cluster score.
    """
    
    # Calculate mean frequency for each cluster
    mean_frequency_per_cluster = df.groupby(clusters)[score].mean()

    # Order clusters based on mean frequency
    ordered_clusters = mean_frequency_per_cluster.sort_values(ascending=ascending).index

    # Map the original cluster labels to the ordered clusters
    df['frequency_cluster'] = df[clusters].map(dict(zip(ordered_clusters, range(len(ordered_clusters)))))

    return df[['frequency_cluster']]

# %%
rfm_df['recency_cluster'] = order_cluster('recency_cluster', 'recency', rfm_df, False)

# %%
rfm_df['recency_cluster'].value_counts()
# Out:
# recency_cluster
# 1    4162
# 2    3844
# 0    3525
# 3    2652
# Name: count, dtype: int64

# %%
sse={}
frequency = rfm_df[['frequency']]

for k in range(1,10):
    kmeans = KMeans(n_clusters=k, max_iter=1000, random_state=42, n_init='auto').fit(frequency)
    frequency['clusters'] = kmeans.labels_
    sse[k] = kmeans.inertia_
    
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of clusters")
plt.show()
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4256860519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frequency['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4256860519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frequency['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4256860519.py:6: SettingWithCopyWarning:
# ...

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(rfm_df[['frequency']])
rfm_df['frequency_cluster'] = kmeans.predict(rfm_df[['frequency']])

# Evaluate the clustering using silhouette score
silhouette_avg = silhouette_score(rfm_df[['frequency']], rfm_df['frequency_cluster'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.9514165004735295

# %%
rfm_df['frequency_cluster'] = order_cluster('frequency_cluster', 'frequency', rfm_df, True)

# %%
rfm_df['frequency_cluster'].value_counts()
# Out:
# frequency_cluster
# 0    8603
# 1    5580
# Name: count, dtype: int64

# %%
sse={}
monetary = rfm_df[['monetary']]

for k in range(1,10):
    kmeans = KMeans(n_clusters=k, max_iter=1000, random_state=42, n_init='auto').fit(monetary)
    monetary['clusters'] = kmeans.labels_
    sse[k] = kmeans.inertia_
    
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of clusters")
plt.show()
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1661994719.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monetary['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1661994719.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monetary['clusters'] = kmeans.labels_
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/1661994719.py:6: SettingWithCopyWarning:
# ...

# %%
# either k=3 or k=4
kmeans = KMeans(n_clusters=4)
kmeans.fit(rfm_df[['monetary']])
rfm_df['monetary_cluster'] = kmeans.predict(rfm_df[['monetary']])
rfm_df['monetary_cluster'] = order_cluster('monetary_cluster', 'monetary', rfm_df, True)

# Evaluate the clustering using silhouette score
silhouette_avg = silhouette_score(rfm_df[['monetary']], rfm_df['monetary_cluster'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.5416666706078227

# %%
rfm_df['monetary_cluster'].value_counts()
# Out:
# monetary_cluster
# 2    4385
# 1    4179
# 0    2876
# 3    2743
# Name: count, dtype: int64

# %%
rfm_df.describe().T
# Out:
#                      count          mean       std       min       25%  \
# recency            14183.0 -1.302553e-17  1.000035 -2.073018 -0.761936
# frequency          14183.0 -3.356579e-17  1.000035 -0.793872 -0.793872
# monetary           14183.0  1.302553e-17  1.000035 -3.762445 -0.746821
# recency_cluster    14183.0  1.396461e+00  1.053756  0.000000  1.000000
# frequency_cluster  14183.0  1.493196e+00  1.020972  0.000000  1.000000
# monetary_cluster   14183.0  1.493196e+00  1.020972  0.000000  1.000000
#
#                         50%       75%       max
# recency            0.050094  0.805997  1.805154
# frequency         -0.793872  1.038056  1.678339
# monetary           0.006687  0.745538  2.609437
# recency_cluster    1.000000  2.000000  3.000000
# frequency_cluster  2.000000  2.000000  3.000000
# monetary_cluster   2.000000  2.000000  3.000000

# %%
rfm_df.groupby('recency_cluster')['recency'].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# recency_cluster
# 0                3525.0  1.265134  0.281255  0.811757  1.016766  1.249702
# 1                4162.0  0.361061  0.253961 -0.081046  0.145295  0.355360
# 2                3844.0 -0.522435  0.263272 -1.005127 -0.743580 -0.515769
# 3                2652.0 -1.490986  0.301048 -2.073018 -1.771599 -1.471677
#
#                       75%       max
# recency_cluster
# 0                1.492158  1.805154
# 1                0.577742  0.811246
# 2               -0.294804 -0.081837
# 3               -1.227234 -1.005873

# %%
rfm_df.groupby('frequency_cluster')['frequency'].describe()
# Out:
#                     count      mean       std       min       25%       50%  \
# frequency_cluster
# 0                  2876.0 -0.790687  0.076330 -0.793872 -0.793872 -0.793872
# 1                  4179.0 -0.607567  0.553770 -0.793872 -0.793872 -0.793872
# 2                  4385.0  0.274112  0.931949 -0.793872 -0.793872  1.038056
# 3                  2743.0  1.316462  0.488165 -0.793872  1.038056  1.505890
#
#                         75%       max
# frequency_cluster
# 0                 -0.793872  1.038056
# 1                 -0.793872  1.038056
# 2                  1.038056  1.678339
# 3                  1.678339  1.678339

# %%
rfm_df.groupby('monetary_cluster')['monetary'].describe()
# Out:
#                    count      mean       std       min       25%       50%  \
# monetary_cluster
# 0                 2876.0 -1.387888  0.354884 -3.762445 -1.614322 -1.284745
# 1                 4179.0 -0.454424  0.258074 -0.919236 -0.660971 -0.453838
# 2                 4385.0  0.447872  0.268324 -0.001997  0.219511  0.435457
# 3                 2743.0  1.431529  0.343456  0.942710  1.138533  1.379239
#
#                        75%       max
# monetary_cluster
# 0                -1.113614 -0.922537
# 1                -0.227852 -0.002511
# 2                 0.673873  0.941845
# 3                 1.662954  2.609437

# %%
#overall scoring
rfm_df['total_score'] = rfm_df['recency_cluster'] + rfm_df['frequency_cluster'] + rfm_df['monetary_cluster']
#rfm_df['total_score'] = rfm_df['recency_cluster'] + rfm_df['monetary_cluster']

# %%
rfm_df.groupby('total_score')[['recency', 'frequency', 'monetary']].mean()
#rfm_df.groupby('total_score')[['recency', 'monetary']].mean()
# Out:
#               recency  frequency  monetary
# total_score
# 0            1.278249  -0.791827 -1.387700
# 1            0.375590  -0.791769 -1.386221
# 2            0.650229  -0.710065 -0.794547
# 3           -0.123408  -0.672099 -0.697228
# 4            0.374663  -0.236754 -0.012862
# 5           -0.275260  -0.026667  0.134170
# 6           -0.114765   0.560922  0.679139
# 7           -0.639150   0.816167  0.911439
# 8           -0.533554   1.356779  1.445398
# 9           -1.487892   1.406739  1.475846

# %% [markdown]
# Based on this scores the customers are put into segments:
#
# #### Lost Customers (Inactive):
# Total Score: 0
# Interpretation: Customers with the highest recency, lowest frequency, and lowest monetary value.
#
# #### At Risk:
# Total Score: 1-2
# Interpretation: Customers with moderate recency, frequency, and monetary values but showing signs of decline.
#
# #### Average Customers:
# Total Score: 3-4
# Interpretation: Customers with moderate recency, frequency, and monetary values. These are stable customers.
#
# #### Good Customers:
# Total Score: 5-6
# Interpretation: Customers with good recency, frequency, and monetary values. Valuable and engaged.
#
# #### Best Customers:
# Total Score: 7-9
# Interpretation: Customers with the highest recency, frequency, and monetary values. These are your most valuable and loyal customers.

# %%
# Assuming you have weights w_recency, w_frequency, w_monetary
#rfm_df['total_score_weighted'] = (w_recency * rfm_df['recency_cluster'] +
#                                  w_frequency * rfm_df['frequency_cluster'] +
#                                  w_monetary * rfm_df['monetary_cluster'])

# %%
def define_segments(x):
    """
    Takes total score and assigns it to a customer segment according to the defined ranges.
    """

    if x == 0:
        return 'Lost Customers'
    elif 0 < x <= 2:
        return 'At Risk'
    elif 2 < x <= 4:
        return 'Average Customers'
    elif 4 < x <= 6:
        return 'Good Customers'
    else:
        return 'Best Customers'

# %%
rfm_df.loc[:, 'customer_segment'] = rfm_df['total_score'].apply(define_segments)

# %%
display(rfm_df['customer_segment'].value_counts())

sns.countplot(rfm_df, x='customer_segment')
plt.tight_layout()
plt.show()
# Out:
# customer_segment
# Average Customers    3799
# Good Customers       3557
# Best Customers       3202
# At Risk              2729
# Lost Customers        896
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

sns.histplot(rfm_df, x= 'recency', ax=ax[0])
sns.countplot(rfm_df, x= 'frequency', ax=ax[1]) #as the feature is discret
sns.histplot(rfm_df, x= 'monetary', ax=ax[2])
plt.tight_layout()

# %% [markdown]
# - Right-skewed recency: Most customers have made recent purchases, and there is a long tail of customers who haven't made purchases for a longer time. Remember, before the customers that haven't purchased anything in 3 years were already filtered out.
#
# - Right-skewed monetary: Most customers have lower monetary values, and there is a long tail of customers with some higher monetary values.
#
# - Low frequency: Most customers are one time purchasers. Maximum of purchase counts is 4.

# %%
df[['recency_cluster', 'frequency_cluster', 'monetary_cluster', 'total_score', 'customer_segment']] = rfm_df[['recency_cluster', 'frequency_cluster', 'monetary_cluster', 'total_score', 'customer_segment']]

# %%
df.head()
# Out:
#    user_id          registration_date  age gender          city  \
# 0       18  2020-06-18 10:15:00+00:00   31      M  Schwedt/Oder
# 1       29  2023-09-22 07:18:00+00:00   23      M        Pudsey
# 2       49  2023-04-11 02:46:00+00:00   62      M      Bailleul
# 3       50  2023-05-01 13:46:00+00:00   15      F       Linares
# 4       51  2019-07-11 00:19:00+00:00   66      M        Siegen
#
#           country           first_order_date            last_order_date  \
# 0          Poland  2021-05-26 10:15:00+00:00  2021-05-26 10:15:00+00:00
# 1  United Kingdom  2023-11-29 07:18:00+00:00  2023-11-29 07:18:00+00:00
# 2          France  2023-08-20 02:46:00+00:00  2023-08-20 02:46:00+00:00
# 3           Spain  2023-07-10 13:46:00+00:00  2023-09-27 13:46:00+00:00
# 4         Germany  2021-08-15 00:19:00+00:00  2021-08-15 00:19:00+00:00
#
#    total_orders  avg_order_items  ...  order_frequency_per_year  \
# 0             1              1.0  ...              3.818439e-16
# ...

# %%
# average customers those customers that should be heavily targeted now to keep them buying?
# maintain best and good customers and enhance relationship

# %%
fig, ax = plt.subplots(2, 1, figsize=(6,9))
sns.violinplot(df, x='total_orders', y='customer_segment', ax=ax[0])
sns.violinplot(df, x='days_since_last_order', y='customer_segment', ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6,9))
sns.scatterplot(df, x='days_since_last_order', y='total_revenue', hue='customer_segment')
plt.show()

# %%
rfm_df2 = df[['user_id', 'days_since_last_order', 'total_orders', 'total_revenue']]
rfm_df2.columns = ['user_id', 'recency', 'frequency', 'monetary']

# %%
rfm_df2
# Out:
#        user_id     recency  frequency    monetary
# 0           18  974.505316          1   46.990002
# 1           29   57.628233          1   65.680000
# 2           49  158.817122          1   65.000000
# 3           50  120.358788          2  512.740005
# 4           51  893.919205          1  120.000000
# ...        ...         ...        ...         ...
# 14178    99951  711.496288          1   46.000000
# 14179    99962  369.285177          3  347.940004
# 14180    99982  752.416427          2  383.900002
# 14181    99997   88.411566          1   12.950000
# 14182    99999   30.229622          2   96.000000
#
# [14183 rows x 4 columns]

# %%
rfm_df2.dtypes
# Out:
# user_id        int64
# recency      float64
# frequency      int64
# monetary     float64
# dtype: object

# %%
quantiles = rfm_df2.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'user_id': {0.25: 24809.0, 0.5: 49568.0, 0.75: 74782.5},
#  'recency': {0.25: 74.46642727527778,
#   0.5: 227.7657328308333,
#   0.75: 493.2705939419444},
#  'frequency': {0.25: 1.0, 0.5: 1.0, 0.75: 2.0},
#  'monetary': {0.25: 44.7549991607666,
#   0.5: 118.9800033569336,
#   0.75: 323.96499729156494}}

# %%
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FMClass(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def RClass(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
rfm_new = rfm_df2
rfm_new['R_Quartile'] = rfm_df2['recency'].apply(RClass, args=('recency',quantiles,))
rfm_new['F_Quartile'] = rfm_df2['frequency'].apply(FMClass, args=('frequency',quantiles,))
rfm_new['M_Quartile'] = rfm_df2['monetary'].apply(FMClass, args=('monetary',quantiles,))


rfm_new['RFMClass'] = rfm_new.R_Quartile.map(str) \
                            + rfm_new.F_Quartile.map(str) \
                            + rfm_new.M_Quartile.map(str)

rfm_new
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4232431997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_new['R_Quartile'] = rfm_df2['recency'].apply(RClass, args=('recency',quantiles,))
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4232431997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_new['F_Quartile'] = rfm_df2['frequency'].apply(FMClass, args=('frequency',quantiles,))
# ...

# %% [markdown]
# ## Clustering customers without RFM scoring model

# %%
# only have chosen 2 features - the total_orders should have been added too
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.histplot(rfm_new, x='recency', ax=ax[0])
sns.histplot(rfm_new, x='frequency', ax=ax[1])
sns.histplot(rfm_new, x='monetary', ax=ax[2])
plt.show()

# %%
# Log-transform 'recency' and 'monetary'
rfm_df2['recency_log'] = np.log1p(rfm_df2['recency'])
rfm_df2['monetary_log'] = np.log1p(rfm_df2['monetary'])

X = rfm_new[['recency_log', 'frequency', 'monetary_log']]
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/34758193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df2['recency_log'] = np.log1p(rfm_df2['recency'])
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/34758193.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df2['monetary_log'] = np.log1p(rfm_df2['monetary'])

# %%
# lets try to cluster without the rfm
from sklearn.preprocessing import StandardScaler

import pickle

scaler2 = StandardScaler()
scaler2.fit(X)
X_scaled = scaler2.transform(X)
#filename = "scaler.pickle" # Path with filename

#with open(filename, "wb") as file:
#        pickle.dump(scaler,file)

X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X_scaled_df.head())
# Out:
#    recency_log  frequency  monetary_log
# 0     1.263679  -0.671648     -0.723153
# 1    -0.732370  -0.671648     -0.473868
# 2    -0.020474  -0.671648     -0.481637
# 3    -0.215894   0.459301      1.073634
# 4     1.202470  -0.671648     -0.022243

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X_scaled_df)
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4, random_state=42)

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index() # Number of customers in each cluster
# Out:
# 0    2543
# 1    5926
# 2    1778
# 3    3936
# Name: count, dtype: int64

# %%
#X_df = pd.DataFrame(X)
X["cluster_kmean"] = clusters
X.head()
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/2071009054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["cluster_kmean"] = clusters
#    recency_log  frequency  monetary_log  cluster_kmean
# 0     6.882956          1      3.870993              1
# 1     4.071216          1      4.199905              0
# 2     5.074030          1      4.189655              1
# 3     4.798751          2      6.241717              3
# 4     6.796733          1      4.795791              1

# %%
#measures how good the kmeans cluster is
kmeans.inertia_
# Out:
# 12671.544781529596

# %%
from sklearn.metrics import silhouette_score
K = range(2, 12)

inertia = []
silhouette = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234,
                    verbose=1)
    kmeans.fit(X_scaled_df)
    
    path = '../scalers/'
    filename = "kmeans_" + str(k) + ".pickle" # Path with filename # kmeans_n.pickle
    with open(path+filename, "wb") as file:
        pickle.dump(kmeans,file)

    inertia.append(kmeans.inertia_)
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,2,figsize=(16,8))
ax[0].plot(K, inertia, 'bx-')
ax[0].set_xlabel('k')
ax[0].set_ylabel('inertia')
ax[0].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[0].set_title('Elbow Method showing the optimal k')
ax[1].plot(K, silhouette, 'bx-')
ax[1].set_xlabel('k')
ax[1].set_ylabel('silhouette score')
ax[1].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[1].set_title('Silhouette Method showing the optimal k')

# %%
# elbow suggests k=3 or k=4
# silhouette shows only peak at k=2

# %%
def load(filename = "filename.pickle"):
    try:
        with open(filename, "rb") as file:
            return pickle.load(file)
    except FileNotFoundError:
        print("File not found!")

# %%
#best_model = load("../scalers/kmeans_3.pickle")
best_model =

# %%
X_scaled_df['kmeans_3_cluster'] = best_model.predict(X_scaled_df)

# %%
X_scaled_df

# %%
from sklearn.metrics import silhouette_score

# Visualize the clusters (replace 'feature1' and 'feature2' with your actual features)
plt.scatter(X['recency_log'], X['monetary_log'], c=X['cluster_kmean'], cmap='viridis')
plt.xlabel('days_since_last_order')
plt.ylabel('total_revenue')
plt.title('Customer Segmentation')
plt.show()

# Evaluate the clustering using silhouette score
silhouette_avg = silhouette_score(X_scaled_df, clusters)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.38597458546395835

# %%
df.head()
# Out:
#    user_id          registration_date  age gender          city  \
# 0       18  2020-06-18 10:15:00+00:00   31      M  Schwedt/Oder
# 1       29  2023-09-22 07:18:00+00:00   23      M        Pudsey
# 2       49  2023-04-11 02:46:00+00:00   62      M      Bailleul
# 3       50  2023-05-01 13:46:00+00:00   15      F       Linares
# 4       51  2019-07-11 00:19:00+00:00   66      M        Siegen
#
#           country           first_order_date            last_order_date  \
# 0          Poland  2021-05-26 10:15:00+00:00  2021-05-26 10:15:00+00:00
# 1  United Kingdom  2023-11-29 07:18:00+00:00  2023-11-29 07:18:00+00:00
# 2          France  2023-08-20 02:46:00+00:00  2023-08-20 02:46:00+00:00
# 3           Spain  2023-07-10 13:46:00+00:00  2023-09-27 13:46:00+00:00
# 4         Germany  2021-08-15 00:19:00+00:00  2021-08-15 00:19:00+00:00
#
#    total_orders  avg_order_items  ...  order_frequency_per_year  \
# 0             1              1.0  ...              3.818439e-16
# ...

# %%
X2 = df[['days_since_last_order', 'total_orders', 'total_revenue']]

scaler3 = StandardScaler()
scaler3.fit(X2)
X_scaled2 = scaler3.transform(X2)
#filename = "scaler.pickle" # Path with filename

#with open(filename, "wb") as file:
#        pickle.dump(scaler,file)

X_scaled_df2 = pd.DataFrame(X_scaled2, columns = X2.columns)


kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X_scaled_df2)
clusters2 = kmeans.predict(X_scaled_df2)

X2["cluster_kmean"] = clusters2

# Visualize the clusters (replace 'feature1' and 'feature2' with your actual features)
sns.scatterplot(x='days_since_last_order', y='total_revenue', data=X2, hue='cluster_kmean', palette='tab10', marker='o')
plt.xlabel('Days Since Last Order')
plt.ylabel('Total Revenue')
plt.title('Customer Segmentation')
plt.legend(title='Cluster')

plt.show()

# Evaluate the clustering using silhouette score
silhouette_avg = silhouette_score(X_scaled_df2, clusters2)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_10268/4203685419.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X2["cluster_kmean"] = clusters2
# Silhouette Score: 0.4708107223654597

# %%
df['kmeans_cluster'] = X2["cluster_kmean"]
df['log_kmeans_cluster'] = X["cluster_kmean"]

# %%
#df['customer_segment_kmeans'] = X2["cluster_kmean"].map({4: 'Best Customers', 1: 'Good Customers', 2: 'At Risk', 0: 'Average Customers', 3: 'Lost Customers'})

# %%
df.to_csv('../data/cleaned/customer_information_with_segments.csv', index=False)
