# %% [markdown]
# # E-Commerce - Users and Orders EMEA
# ## Data Cleaning
#
# "TheLook is a fictitious eCommerce clothing site developed by the Looker team. The dataset contains information about customers, products, orders, logistics, web events and digital marketing campaigns. The contents of this dataset are synthetic, and are provided to industry practitioners for the purpose of product discovery, testing, and evaluation."
#
# Not all information will be subject in this project. The further analysis will be conducted based on the following query.
#
# The data frame contains information about registered users of the fictional E-commerce store.
# If a user made a purchase the data frame will also list information about the respective order.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timezone

# %%
df = pd.read_csv('../data/raw/ecommerce_users_orders_europe.csv')

# %%
df.head()
# Out:
#    user_id first_name last_name  age gender      state  \
# 0    30231    Michael     Burch   25      M  Andalucía
# 1    63740       Ryan     Munoz   41      M  Andalucía
# 2    81229    Bradley     Gomez   30      M  Andalucía
# 3    83889   Jennifer    Morgan   52      F  Andalucía
# 4    83889   Jennifer    Morgan   52      F  Andalucía
#
#                 street_address postal_code                 city country  \
# 0          40146 Ferguson Road        4117  San Isidro de Níjar   Spain
# 1         577 Laurie Stravenue        4117  San Isidro de Níjar   Spain
# 2              61977 Sara Neck        4117  San Isidro de Níjar   Spain
# 3  248 Murphy Parkway Apt. 083        4100         Campohermoso   Spain
# 4  248 Murphy Parkway Apt. 083        4100         Campohermoso   Spain
#
#              registered_on user_traffic_source  order_id order_status  \
# 0  2019-08-04 17:10:00 UTC              Search       NaN          NaN
# 1  2023-02-16 00:23:00 UTC              Search   79733.0    Cancelled
# 2  2021-10-30 06:51:00 UTC             Organic  101551.0    Cancelled
# 3  2020-03-31 17:12:00 UTC             Organic  104928.0    Cancelled
# 4  2020-03-31 17:12:00 UTC             Organic  104927.0   Processing
#
#           order_created_at  num_of_item    revenue
# 0                      NaN          NaN        NaN
# 1  2023-07-05 00:23:00 UTC          1.0  89.989998
# 2  2022-04-25 06:51:00 UTC          2.0  29.980000
# 3  2021-10-27 17:12:00 UTC          1.0  30.209999
# 4  2023-08-03 17:12:00 UTC          1.0  30.209999

# %%
df.describe()
# Out:
#             user_id           age       order_id   num_of_item       revenue
# count  27734.000000  27734.000000   23837.000000  23837.000000  23837.000000
# mean   49949.081885     41.000108   62282.122583      1.450854    177.780300
# std    28767.217681     17.066364   35952.180017      0.809142    163.481417
# min       18.000000     12.000000      19.000000      1.000000      0.490000
# 25%    25049.500000     26.000000   31024.000000      1.000000     59.020002
# 50%    49914.500000     41.000000   62263.000000      1.000000    130.450001
# 75%    74803.250000     56.000000   93348.000000      2.000000    246.480007
# max    99999.000000     70.000000  124831.000000      4.000000   1308.989998

# %%
df.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'age', 'gender', 'state',
#        'street_address', 'postal_code', 'city', 'country', 'registered_on',
#        'user_traffic_source', 'order_id', 'order_status', 'order_created_at',
#        'num_of_item', 'revenue'],
#       dtype='object')

# %%
df.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# age                      int64
# gender                  object
# state                   object
# street_address          object
# postal_code             object
# city                    object
# country                 object
# registered_on           object
# user_traffic_source     object
# order_id               float64
# order_status            object
# order_created_at        object
# num_of_item            float64
# revenue                float64
# dtype: object

# %%
# first convert the date columns to datetime
date_cols = ['registered_on', 'order_created_at']

for col in date_cols:
    df[col] = pd.to_datetime(df[col], origin='unix', format='mixed', utc=True)

# %%
# the id columns need to be object
df[['user_id', 'order_id']] = df[['user_id', 'order_id']].astype(object)
df.dtypes
# Out:
# user_id                             object
# first_name                          object
# last_name                           object
# age                                  int64
# gender                              object
# state                               object
# street_address                      object
# postal_code                         object
# city                                object
# country                             object
# registered_on          datetime64[ns, UTC]
# user_traffic_source                 object
# order_id                            object
# order_status                        object
# order_created_at       datetime64[ns, UTC]
# num_of_item                        float64
# revenue                            float64
# dtype: object

# %%
for_unique_check = ['age', 'gender', 'state', 'country',
                    'user_traffic_source', 'order_status', 'num_of_item']

for col in for_unique_check:
    print(col)
    print(df[col].unique())
# Out:
# age
# [25 41 30 52 50 60 44 57 69 53 47 12 54 14 32 38 62 17 65 68 22 27 58 18
#  36 26 59 29 61 35 64 42 28 34 66 55 39 20 24 21 16 40 19 70 15 67 43 56
#  31 48 23 33 45 13 37 51 46 49 63]
# gender
# ['M' 'F']
# state
# ['Andalucía' 'Aragón' 'Auvergne-Rhône-Alpes' 'Baden-Württemberg' 'Bayern'
#  'Berlin' 'Bourgogne-Franche-Comté' 'Brandenburg' 'Bremen' 'Bretagne'
#  'Brussels' 'Canarias' 'Cantabria' 'Castilla y León' 'Castilla-La Mancha'
#  'Cataluña' 'Centre-Val de Loire' 'Ceuta' 'Comunidad Valenciana'
#  'Comunidad de Madrid' 'Corse' 'Dolnośląskie' 'England' 'Extremadura'
#  'Flanders' 'Galicia' 'Grand Est' 'Hamburg' 'Hauts-de-France' 'Hessen'
#  'Islas Baleares' 'La Rioja' 'Lubuskie' 'Mecklenburg-Vorpommern' 'Melilla'
#  'Navarra' 'Niedersachsen' 'Nordrhein-Westfalen' 'Normandie'
#  'Northern Ireland' 'Nouvelle-Aquitaine' 'Occitanie' 'Pays de la Loire'
#  'País Vasco' 'Principado de Asturias' "Provence-Alpes-Côte d'Azur"
#  'Región de Murcia' 'Rheinland-Pfalz' 'Saarland' 'Sachsen'
#  'Sachsen-Anhalt' 'Schleswig-Holstein' 'Scotland' 'Thüringen' 'Vorarlberg'
#  'Wales' 'Wallonia' 'Zachodniopomorskie' 'Île-de-France']
# country
# ['Spain' 'France' 'Germany' 'Belgium' 'Poland' 'United Kingdom' 'España'
#  'Austria']
# user_traffic_source
# ['Search' 'Organic' 'Facebook' 'Email' 'Display']
# order_status
# [nan 'Cancelled' 'Processing' 'Complete' 'Shipped' 'Returned']
# num_of_item
# [nan  1.  2.  4.  3.]

# %%
# clean country: 'España' -> 'Spain'
df['country'].replace('España', 'Spain', inplace=True)

# %%
df.isnull().sum()
# Out:
# user_id                   0
# first_name                0
# last_name                 0
# age                       0
# gender                    0
# state                     0
# street_address            0
# postal_code               0
# city                     77
# country                   0
# registered_on             0
# user_traffic_source       0
# order_id               3897
# order_status           3897
# order_created_at       3897
# num_of_item            3897
# revenue                3897
# dtype: int64

# %% [markdown]
# There are missing values in the city column.
# Further, 3897 users haven't ordered on the platform yet. This information (rows) can be useful later on for creating prediction models. Therefore, I will split the df into two parts: one containing users with orders, and the other with users that haven't made an order yet.

# %%
#Let's have a look at the nans in the city column
df[df['city'].isna()][['postal_code','country', 'user_id']].value_counts()
# Out:
# postal_code  country  user_id
# 15174        Spain    5251       4
# 30835        Spain    31512      4
# 50059        Spain    6050       4
# 33129        Germany  82934      4
# 30835        Spain    95195      3
# 50016        Spain    82596      3
# 50197        Spain    54913      2
# 41130        Spain    53137      2
#                       74246      2
# 28946        Spain    77770      2
#                       88627      2
# 50059        Spain    74981      2
# 29140        Spain    11543      2
# 30835        Spain    89589      2
# 50016        Spain    78479      1
# 41130        Spain    89782      1
#                       99612      1
# 46988        Spain    36005      1
#                       82365      1
# 50016        Spain    13195      1
# 50059        Spain    3504       1
# 50016        Spain    90220      1
# 38434        Spain    6837       1
# 15174        Spain    58992      1
# 50059        Spain    25982      1
#                       63941      1
# 50191        Spain    27228      1
# 50197        Spain    1540       1
#                       10498      1
#                       15752      1
# 41130        Spain    33093      1
# 25191        Spain    47490      1
# 38300        Spain    33758      1
# 29140        Spain    82510      1
# 28909        Spain    16192      1
# 28946        Spain    47511      1
#                       48724      1
#                       49126      1
# 28947        Spain    70480      1
#                       86686      1
# 29140        Spain    27960      1
#                       77846      1
#                       94127      1
# 38300        Spain    33194      1
# 30835        Spain    3044       1
# 15174        Spain    89209      1
# 30835        Spain    62096      1
#                       67215      1
# 33129        Germany  59421      1
# 15174        Spain    57949      1
# 38297        Spain    11831      1
# 28524        Spain    11423      1
# 38300        Spain    24264      1
# Name: count, dtype: int64

# %% [markdown]
# Either could webscrap the postal codes or just drop the rows.
# I will look up the Germany postal code and fill the city manually.

# %%
missing_city_ger = {'33129': "Delbrück"}
df['city'] = df['city'].fillna(df['postal_code'].map(missing_city_ger))

# %%
zipcode_nan_cities = df[df['city'].isna()]['postal_code'].drop_duplicates().tolist()
zipcode_nan_cities
# Out:
# ['29140',
#  '41130',
#  '50016',
#  '50059',
#  '50191',
#  '50197',
#  '38297',
#  '38300',
#  '38434',
#  '25191',
#  '46988',
#  '28524',
#  '28909',
#  '28947',
#  '28946',
#  '15174',
#  '30835']

# %%
#checking if there is an entry with these postal codes
df[(df['postal_code'].isin(zipcode_nan_cities)) & (df['city'].notna()) & (df['country'] == "Spain")]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, age, gender, state, street_address, postal_code, city, country, registered_on, user_traffic_source, order_id, order_status, order_created_at, num_of_item, revenue]
# Index: []

# %%
df[(df['user_id']==5251)]
# Out:
#       user_id first_name last_name  age gender    state    street_address  \
# 15833    5251    Heather  Martinez   33      F  Galicia  15864 Amber Port
# 15834    5251    Heather  Martinez   33      F  Galicia  15864 Amber Port
# 15835    5251    Heather  Martinez   33      F  Galicia  15864 Amber Port
# 15836    5251    Heather  Martinez   33      F  Galicia  15864 Amber Port
#
#       postal_code city country             registered_on user_traffic_source  \
# 15833       15174  NaN   Spain 2021-04-07 18:59:00+00:00              Search
# 15834       15174  NaN   Spain 2021-04-07 18:59:00+00:00              Search
# 15835       15174  NaN   Spain 2021-04-07 18:59:00+00:00              Search
# 15836       15174  NaN   Spain 2021-04-07 18:59:00+00:00              Search
#
#       order_id order_status          order_created_at  num_of_item     revenue
# 15833   6474.0    Cancelled 2022-07-23 18:59:00+00:00          1.0  131.740003
# 15834   6473.0   Processing 2023-05-25 18:59:00+00:00          1.0  131.740003
# 15835   6476.0     Returned 2022-10-17 18:59:00+00:00          1.0  131.740003
# 15836   6475.0      Shipped 2021-05-22 18:59:00+00:00          1.0  131.740003

# %%
df = df.dropna(subset=['city'])

# %% [markdown]
# Either could webscrap the postal codes or just drop the rows.

# %%
df.shape
# Out:
# (27662, 17)

# %%
#look for duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
# let's define since when the users are registered (in days)
reference_date = datetime.utcnow().replace(tzinfo=timezone.utc)
df['days_since_registration'] = (reference_date - df['registered_on']).dt.days
df[['registered_on','days_since_registration']].head()
# Out:
#               registered_on  days_since_registration
# 0 2019-08-04 17:10:00+00:00                     1635
# 1 2023-02-16 00:23:00+00:00                      343
# 2 2021-10-30 06:51:00+00:00                      817
# 3 2020-03-31 17:12:00+00:00                     1395
# 4 2020-03-31 17:12:00+00:00                     1395

# %%
# investigating the data set and the user order behaviour
pivot_table = pd.pivot_table(df, index='user_id', values='order_id', aggfunc='count', fill_value=0)

# Display the pivot table to inspect the number of orders by user

min_orders_value = pivot_table.min()['order_id']
max_orders_value = pivot_table.max()['order_id']

print(f"Number of min orders: {min_orders_value}")
print(f"Number of max orders: {max_orders_value}")
# Out:
# Number of min orders: 0
# Number of max orders: 4

# %%
df.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'age', 'gender', 'state',
#        'street_address', 'postal_code', 'city', 'country', 'registered_on',
#        'user_traffic_source', 'order_id', 'order_status', 'order_created_at',
#        'num_of_item', 'revenue', 'has_ordered', 'days_since_registration'],
#       dtype='object')

# %%
# split data set in users with orders and users without orders
# prediction if order will be returned
# when user is ordering
# calculate rfm

# %%
df['user_id'].nunique()
# Out:
# 19155

# %%
# Creating a Customer-Level DataFrame
customer_df = df.groupby(['user_id', 'registered_on', 'age', 'gender', 'city', 'country']).agg({
    'order_created_at': ['min', 'max'],  # Min and Max for recency
    'order_id': 'nunique',                # Number of orders for frequency
    'num_of_item': 'mean',                # Average number of items of order
    'revenue': ['sum', 'mean']            # Total revenue of orders (CLV) and average revenugre
}).reset_index()


customer_df.columns = ['user_id', 'registration_date', 'age', 'gender', 'city',
                       'country', 'first_order_date', 'last_order_date', 
                       'total_orders', 'avg_order_items', 'total_revenue', 'avg_order_value']

# %%
# Additional Feature Engineering

customer_df['order_frequency_per_year'] = customer_df['total_orders'] / (pd.to_datetime('now', utc=True) - customer_df['first_order_date']).dt.total_seconds() / (60 * 60 * 24 * 30 *12)
customer_df['days_since_first_order'] = (pd.to_datetime('now', utc=True) - customer_df['first_order_date']).dt.total_seconds() / (60 * 60 * 24)
customer_df['days_since_last_order'] = (pd.to_datetime('now', utc=True) - customer_df['last_order_date']).dt.total_seconds() / (60 * 60 * 24)
customer_df['days_since_registration'] = (pd.to_datetime('now', utc=True) - customer_df['registration_date']).dt.total_seconds() / (60 * 60 * 24)
customer_df['days_until_first_order'] = (customer_df['first_order_date'] - customer_df['registration_date']).dt.total_seconds() / (60 * 60 * 24)

# as mentioned before, there are users that haven't ordered yet
customer_df['has_ordered'] = customer_df['first_order_date'].apply(lambda x: 0 if pd.isna(x) else 1)
# Display the updated customer DataFrame
display(customer_df.head())
# Out:
#    user_id         registration_date  age gender          city  \
# 0       18 2020-06-18 10:15:00+00:00   31      M  Schwedt/Oder
# 1       20 2020-12-20 03:57:00+00:00   57      M      Castalla
# 2       29 2023-09-22 07:18:00+00:00   23      M        Pudsey
# 3       30 2020-02-18 07:06:00+00:00   36      F        Fréjus
# 4       33 2019-02-14 17:19:00+00:00   12      M     Bogatynia
#
#           country          first_order_date           last_order_date  \
# 0          Poland 2021-05-26 10:15:00+00:00 2021-05-26 10:15:00+00:00
# 1           Spain                       NaT                       NaT
# 2  United Kingdom 2023-11-29 07:18:00+00:00 2023-11-29 07:18:00+00:00
# 3          France                       NaT                       NaT
# 4          Poland 2020-06-02 17:19:00+00:00 2020-06-11 17:19:00+00:00
#
#    total_orders  avg_order_items  total_revenue  avg_order_value  \
# 0             1              1.0      46.990002        46.990002
# 1             0              NaN       0.000000              NaN
# 2             1              2.0      65.680000        65.680000
# 3             0              NaN       0.000000              NaN
# 4             2              1.0      73.959999        36.980000
#
#    order_frequency_per_year  days_since_first_order  days_since_last_order  \
# 0              3.818439e-16              974.505316             974.505316
# 1                       NaN                     NaN                    NaN
# 2              6.457058e-15               57.628233              57.628233
# 3                       NaN                     NaN                    NaN
# 4              5.586336e-16             1332.210872            1323.210872
#
#    days_since_registration  days_until_first_order  has_ordered
# 0              1316.505316                   342.0            1
# 1              1131.767816                     NaN            0
# 2               125.628233                    68.0            1
# 3              1437.636566                     NaN            0
# 4              1806.210872                   474.0            1

# %%
customer_df.dtypes
# Out:
# user_id                                   int64
# registration_date           datetime64[ns, UTC]
# age                                       int64
# gender                                   object
# city                                     object
# country                                  object
# first_order_date            datetime64[ns, UTC]
# last_order_date             datetime64[ns, UTC]
# total_orders                              int64
# avg_order_items                         float64
# total_revenue                           float64
# avg_order_value                         float64
# order_frequency_per_year                float64
# days_since_first_order                  float64
# days_since_last_order                   float64
# days_since_registration                 float64
# days_until_first_order                  float64
# has_ordered                               int64
# dtype: object

# %%
# the id columns need to be object
customer_df['user_id'] = customer_df['user_id'].astype(object)

# %%
print(customer_df.shape)
# Out:
# (19104, 18)

# %% [markdown]
# ## EDA

# %%
age_counts = customer_df['age'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=age_counts.index, y=age_counts.values, color='skyblue')
plt.title('Users by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Adding age groups:
bins = [0, 18, 30, 40, 50, 60, 70, 120]
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61-70', '71+']

customer_df['age_class'] = pd.cut(customer_df['age'], bins=bins, labels=labels, right=False)
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/462151789.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['age_class'] = pd.cut(customer_df['age'], bins=bins, labels=labels, right=False)

# %%
# Display the count of each age class
age_class_counts = customer_df['age_class'].value_counts().sort_index()
print(age_class_counts)
# Out:
# age_class
# 0-18     1468
# 19-30    2896
# 31-40    2382
# 41-50    2403
# 51-60    2372
# 61-70    2446
# 71+       240
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(customer_df, x='age_class')
plt.title('Users by Age Class')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
print(customer_df['gender'].value_counts())

sns.countplot(customer_df, x='gender').set_title('Gender')
plt.show()
# Out:
# gender
# F    7143
# M    7064
# Name: count, dtype: int64

# %%
customer_df['registration_year'] = customer_df['registration_date'].dt.year
customer_df['registration_month'] = customer_df['registration_date'].dt.month
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/599286830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['registration_year'] = customer_df['registration_date'].dt.year
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/599286830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['registration_month'] = customer_df['registration_date'].dt.month

# %%
print(customer_df['registration_year'].value_counts())
# Out:
# registration_year
# 2021    2976
# 2023    2974
# 2022    2922
# 2020    2626
# 2019    2125
# 2024     584
# Name: count, dtype: int64

# %%
#lets focus on full years and plot the development
customer_df= customer_df[customer_df['registration_year'] != 2024]

# %%
print(customer_df['registration_year'].value_counts())
# Out:
# registration_year
# 2021    2976
# 2023    2974
# 2022    2922
# 2020    2626
# 2019    2125
# Name: count, dtype: int64

# %%
sns.histplot(customer_df, x='registration_date')
plt.title('Registration Date Distribution')
plt.ylabel('Count')
plt.show()

# %%
print(customer_df['country'].value_counts())

sns.countplot(customer_df, x='country').set_title('Users by Country')
plt.tight_layout()
plt.show()
# Out:
# country
# France            3376
# United Kingdom    3344
# Germany           3013
# Spain             2844
# Belgium            865
# Poland             178
# Austria              3
# Name: count, dtype: int64

# %%
g = sns.FacetGrid(customer_df, col='gender', col_wrap=4)
g.map(sns.histplot, 'days_since_last_order')
g.set_titles('{col_name}')
plt.show()
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.FacetGrid(customer_df, col='age', col_wrap=4)
g.map(sns.histplot, 'days_since_last_order')
g.set_titles('{col_name}')
plt.show()
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.FacetGrid(customer_df, col='country', col_wrap=4)
g.map(sns.histplot, 'days_since_last_order')
g.set_titles('{col_name}')
plt.show()
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Combining Violinplots and Boxplots:
#
# Violin plots can be combined with boxplots to show both the summary statistics (boxplot) and the detailed distribution (violin plot) in the same visualization

# %%
365*2
# Out:
# 730

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
sns.boxplot(customer_df, x='days_since_last_order', ax=ax[0])
sns.violinplot(customer_df, x='days_since_last_order', ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
sns.boxplot(customer_df, x='days_since_last_order', y='country', ax=ax[0])
sns.violinplot(customer_df, x='days_since_last_order', y='country', ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
sns.boxplot(customer_df, x='days_since_last_order', y='gender', ax=ax[0])
sns.violinplot(customer_df, x='days_since_last_order', y='gender', ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
sns.boxplot(customer_df, x='days_since_last_order', y='age_class', ax=ax[0])
sns.violinplot(customer_df, x='days_since_last_order', y='age_class', ax=ax[1])
plt.show()

# %%
fig, ax = figsize=(15,5)
sns.histplot(customer_df, x='days_since_registration', hue='has_ordered').set_title('registered overview')
plt.show()

# %%
# limit query to last 12 months?
customer_df.columns
# Out:
# Index(['user_id', 'registration_date', 'age', 'gender', 'city', 'country',
#        'first_order_date', 'last_order_date', 'total_orders',
#        'avg_order_items', 'total_revenue', 'avg_order_value',
#        'order_frequency_per_year', 'days_since_first_order',
#        'days_since_registration', 'days_until_first_order', 'has_ordered',
#        'days_since_last_order', 'age_class', 'registration_year',
#        'registration_month'],
#       dtype='object')

# %%
users_with_orders = customer_df[(customer_df['first_order_date'].notnull())]
users_with_orders.drop(columns='has_ordered', inplace=True)
users_with_orders.shape
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/2685804889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_orders.drop(columns='has_ordered', inplace=True)
# (15224, 17)

# %%
users_with_orders.dtypes
# Out:
# user_id                                  object
# registration_date           datetime64[ns, UTC]
# age                                       int64
# gender                                   object
# city                                     object
# country                                  object
# first_order_date            datetime64[ns, UTC]
# last_order_date             datetime64[ns, UTC]
# total_orders                              int64
# avg_order_items                         float64
# total_revenue                           float64
# avg_order_value                         float64
# order_frequency_per_year                float64
# days_since_first_order                  float64
# days_since_last_order                   float64
# days_since_registration                 float64
# days_until_first_order                  float64
# dtype: object

# %%
users_with_orders.isnull().sum()
# Out:
# user_id                     0
# registration_date           0
# age                         0
# gender                      0
# city                        0
# country                     0
# first_order_date            0
# last_order_date             0
# total_orders                0
# avg_order_items             0
# total_revenue               0
# avg_order_value             0
# order_frequency_per_year    0
# days_since_first_order      0
# days_since_last_order       0
# days_since_registration     0
# days_until_first_order      0
# dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.boxplot(customer_df, x='total_revenue', ax=ax[0])
sns.histplot(customer_df, x='total_revenue', ax=ax[1])
plt.show()

# %%
#drop customers with total_revenue > 4000
customer_df = customer_df[customer_df['total_revenue'] <= 4000]

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.boxplot(customer_df, x='avg_order_value', ax=ax[0])
sns.histplot(customer_df, x='avg_order_value', ax=ax[1])
plt.show()

# %%
users_wo_orders = customer_df[(customer_df['first_order_date'].isna())]
users_wo_orders.shape
# Out:
# (3880, 18)

# %%
users_wo_orders.isnull().sum()
# Out:
# user_id                        0
# registration_date              0
# age                            0
# gender                         0
# city                           0
# country                        0
# first_order_date            3880
# last_order_date             3880
# total_orders                   0
# avg_order_items             3880
# total_revenue                  0
# avg_order_value             3880
# order_frequency_per_year    3880
# days_since_first_order      3880
# days_since_last_order       3880
# days_since_registration        0
# days_until_first_order      3880
# has_ordered                    0
# dtype: int64

# %%
users_wo_orders.dropna(axis=1, inplace=True)
display(users_wo_orders.head())
users_wo_orders.shape
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/3636319674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_wo_orders.dropna(axis=1, inplace=True)
#    user_id         registration_date  age gender               city  \
# 1       20 2020-12-20 03:57:00+00:00   57      M           Castalla
# 3       30 2020-02-18 07:06:00+00:00   36      F             Fréjus
# 5       38 2021-12-11 04:14:00+00:00   57      F           Dartford
# 21     100 2019-03-09 17:35:00+00:00   13      M             London
# 22     110 2021-02-05 16:07:00+00:00   28      M  Romilly-sur-Seine
#
#            country  total_orders  total_revenue  days_since_registration  \
# 1            Spain             0            0.0              1131.767816
# 3           France             0            0.0              1437.636566
# 5   United Kingdom             0            0.0               775.756011
# 21  United Kingdom             0            0.0              1783.199761
# 22          France             0            0.0              1084.260872
#
#     has_ordered
# 1             0
# 3             0
# 5             0
# 21            0
# 22            0
# (3880, 10)

# %% [markdown]
# ## Feature Analysis

# %%
365*3
# Out:
# 1095

# %%
#drop customers with that haven't been active since 3 years
users_with_orders = users_with_orders[users_with_orders['days_since_last_order'] <= (365*3)]

# %%
numerical_cols = users_with_orders.select_dtypes(include='number').columns
categorical_cols = users_with_orders.select_dtypes(exclude='number').columns

# %%
# Calculating the skew for all numerical variables. Check if it is outside range [-2,2].
skew_dict_outside_range = {'vars_outside_range':[], 'Skew':[]}
skew_dict_inside_range = {'vars_in_range':[], 'Skew':[]}
for i in range(len(numerical_cols)):
    if users_with_orders[numerical_cols[i]].skew() <= -2 or users_with_orders[numerical_cols[i]].skew() >= 2:
        skew_dict_outside_range['vars_outside_range'].append(numerical_cols[i])
        skew_dict_outside_range['Skew'].append(users_with_orders[numerical_cols[i]].skew())
    else:
        skew_dict_inside_range['vars_in_range'].append(numerical_cols[i])
        skew_dict_inside_range['Skew'].append(users_with_orders[numerical_cols[i]].skew())

display(pd.DataFrame(skew_dict_outside_range))
display(pd.DataFrame(skew_dict_inside_range))
# Out:
#   vars_outside_range      Skew
# 0      total_revenue  3.410893
# 1    avg_order_value  2.378486
#               vars_in_range      Skew
# 0                       age  0.003363
# 1              total_orders  1.493923
# 2           avg_order_items  1.875722
# 3  order_frequency_per_year  0.000000
# 4    days_since_first_order  0.862086
# 5     days_since_last_order  0.910419
# 6   days_since_registration  0.115407
# 7    days_until_first_order  1.175959

# %%
# Checking overall correlation between variables
correlation_matrix = users_with_orders[numerical_cols].corr().round(4)
correlation_matrix
# Out:
#                              age  total_orders  avg_order_items  \
# age                       1.0000        0.0002          -0.0019
# total_orders              0.0002        1.0000           0.0093
# avg_order_items          -0.0019        0.0093           1.0000
# total_revenue            -0.0163        0.7755           0.2016
# avg_order_value          -0.0208        0.5491           0.4016
# order_frequency_per_year  0.0044        0.0844           0.0072
# days_since_first_order   -0.0057        0.3247           0.0013
# days_since_last_order    -0.0035       -0.2021          -0.0049
# days_since_registration  -0.0129        0.0468           0.0028
# days_until_first_order   -0.0122       -0.2607           0.0025
#
#                           total_revenue  avg_order_value  \
# age                             -0.0163          -0.0208
# total_orders                     0.7755           0.5491
# avg_order_items                  0.2016           0.4016
# total_revenue                    1.0000           0.8783
# avg_order_value                  0.8783           1.0000
# order_frequency_per_year         0.0733           0.0524
# days_since_first_order           0.2268           0.1688
# days_since_last_order           -0.1561          -0.1179
# days_since_registration          0.0290           0.0249
# days_until_first_order          -0.1873          -0.1347
#
#                           order_frequency_per_year  days_since_first_order  \
# age                                         0.0044                 -0.0057
# total_orders                                0.0844                  0.3247
# avg_order_items                             0.0072                  0.0013
# total_revenue                               0.0733                  0.2268
# avg_order_value                             0.0524                  0.1688
# order_frequency_per_year                    1.0000                 -0.2458
# days_since_first_order                     -0.2458                  1.0000
# days_since_last_order                      -0.2274                  0.6782
# days_since_registration                    -0.2927                  0.6920
# days_until_first_order                     -0.1586                 -0.0448
#
#                           days_since_last_order  days_since_registration  \
# age                                     -0.0035                  -0.0129
# total_orders                            -0.2021                   0.0468
# avg_order_items                         -0.0049                   0.0028
# total_revenue                           -0.1561                   0.0290
# avg_order_value                         -0.1179                   0.0249
# order_frequency_per_year                -0.2274                  -0.2927
# days_since_first_order                   0.6782                   0.6920
# days_since_last_order                    1.0000                   0.5642
# days_since_registration                  0.5642                   1.0000
# days_until_first_order                   0.1009                   0.6901
#
#                           days_until_first_order
# age                                      -0.0122
# total_orders                             -0.2607
# avg_order_items                           0.0025
# total_revenue                            -0.1873
# avg_order_value                          -0.1347
# order_frequency_per_year                 -0.1586
# days_since_first_order                   -0.0448
# days_since_last_order                     0.1009
# days_since_registration                   0.6901
# days_until_first_order                    1.0000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.3f')
plt.show()

# %%
def significant_vars (df: pd.DataFrame, y: str, treshold=0.3):
    '''
    Checking all if any corr in the corrleation matrix exceed a given threshold.
    Gathers all that >= treshold or <= -treshold into a list.
    '''
    df2 = df.copy()
    corr_matrix = df2.corr()
    corr_with_y = corr_matrix.loc[:,y].reset_index()

    significant_corr = corr_with_y[(corr_with_y[y]>=treshold) | (corr_with_y[y]<=(-treshold))]
    significant_vars_list = list(significant_corr.iloc[:,0])
    significant_vars_list.remove(y)
    return significant_vars_list

# %%
# listing all variables that have at least some "significant" correlation with total_claim_amount:
significant_vars(users_with_orders[numerical_cols], 'total_revenue', treshold=0.2)
# Out:
# ['total_orders',
#  'avg_order_items',
#  'avg_order_value',
#  'days_since_first_order']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant


# compute the vif for all given columns
def compute_vif(df: pd.DataFrame, columns: list):
    
    # create dataframe only of one column
    X = df[columns]
    # the calculation of variance inflation requires a constant
    X.loc[:,'intercept'] = 1

    # dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif.loc[vif['Variable']!='intercept'].sort_values('VIF', ascending=False).reset_index(drop=True)
    return vif

# %%
# All numerical columns will be considered 
selected_columns = list(numerical_cols)
selected_columns.remove("total_revenue")

# compute vif
vif_df = compute_vif(users_with_orders[numerical_cols], selected_columns)
display(vif_df)
# Out:
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /Users/alinaaufenanger/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1781: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#                    Variable       VIF
# 0    days_since_first_order       inf
# 1   days_since_registration       inf
# 2    days_until_first_order       inf
# 3     days_since_last_order  2.937448
# 4              total_orders  2.406895
# 5           avg_order_value  1.849636
# 6           avg_order_items  1.290933
# 7  order_frequency_per_year  1.121492
# 8                       age  1.000946

# %%
selected_columns
# Out:
# ['age',
#  'total_orders',
#  'avg_order_items',
#  'avg_order_value',
#  'order_frequency_per_year',
#  'days_since_first_order',
#  'days_since_last_order',
#  'days_since_registration',
#  'days_until_first_order']

# %% [markdown]
# - the VIFs are mostly around 1-10
# - VIF 1 means not correlated, VIF 1-5: moderately correlated, VIF >5 correlated

# %%
while any(vif_df['VIF']>3):
    selected_columns.remove(vif_df.iloc[0,0])
    display(vif_df)
    print(selected_columns)
    vif_df = compute_vif(users_with_orders[numerical_cols], selected_columns)

display(vif_df)
print("The final selected columns are: ", selected_columns)
# Out:
#                    Variable       VIF
# 0    days_since_first_order       inf
# 1   days_since_registration       inf
# 2    days_until_first_order       inf
# 3     days_since_last_order  2.937448
# 4              total_orders  2.406895
# 5           avg_order_value  1.849636
# 6           avg_order_items  1.290933
# 7  order_frequency_per_year  1.121492
# 8                       age  1.000946
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/2739581792.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:,'intercept'] = 1
# ['age', 'total_orders', 'avg_order_items', 'avg_order_value', 'order_frequency_per_year', 'days_since_last_order', 'days_since_registration', 'days_until_first_order']
#                    Variable       VIF
# 0   days_since_registration  5.998655
# 1    days_until_first_order  4.225033
# 2     days_since_last_order  2.937448
# 3              total_orders  2.406895
# 4           avg_order_value  1.849636
# 5           avg_order_items  1.290933
# 6  order_frequency_per_year  1.121492
# 7                       age  1.000946
# ['age', 'total_orders', 'avg_order_items', 'avg_order_value', 'order_frequency_per_year', 'days_since_last_order', 'days_until_first_order']
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/2739581792.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:,'intercept'] = 1
#                    Variable       VIF
# 0           avg_order_value  1.849423
# 1              total_orders  1.661539
# 2           avg_order_items  1.290885
# 3    days_until_first_order  1.076010
# 4  order_frequency_per_year  1.075750
# 5     days_since_last_order  1.045406
# 6                       age  1.000914
# The final selected columns are:  ['age', 'total_orders', 'avg_order_items', 'avg_order_value', 'order_frequency_per_year', 'days_since_last_order', 'days_until_first_order']

# %%
# Only those that were checked for signifant correlation will be taken into account. 
# I take these calculated in the significant_vars function earlier:
significant_vars = significant_vars(users_with_orders[numerical_cols], 'total_revenue', treshold=0.2)

vif_df2 = compute_vif(users_with_orders[numerical_cols], significant_vars)
display(vif_df2)
# Out:
# /var/folders/xv/sbmlp5m11vlc8qbxx5xp1lfw0000gp/T/ipykernel_3338/2739581792.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:,'intercept'] = 1
#                  Variable       VIF
# 0         avg_order_value  1.848061
# 1            total_orders  1.674272
# 2         avg_order_items  1.290745
# 3  days_since_first_order  1.118068

# %% [markdown]
# #### Using Features Identified through Correlation:
#
# Advantages:
#
# Simplicity: Fewer features may result in a simpler model that is easier to interpret.
# Interpretability: Using features with higher correlation may make the model more interpretable and align with the domain knowledge.
# Considerations:
#
# Correlation does not imply causation. While a feature may have a strong correlation, it may not necessarily be a causal factor.
#
# #### Using Features Selected Based on VIF:
#
# Advantages:
#
# Addressing Multicollinearity: Features selected based on VIF help address multicollinearity, enhancing the stability and interpretability of the regression coefficients.
# Considerations:
#
# May involve more complex interactions between variables. The selected features might not align with intuitive or domain-driven expectations.

# %%
users_with_orders.to_csv('../data/cleaned/customer_information.csv', index=False)
